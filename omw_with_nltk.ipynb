# %%
#=============================================================
# Title:  Compare two languages with Open Multilingual Wordnet
# Content: functions to calculate the whole hypernym chain, their lemmas and keys
# Author: RitaRuebchen
# Date:   September 2020
#=============================================================

# %%
import nltk
#nltk.download('omw')
from nltk.corpus import wordnet as wn
from itertools import chain

# %%
def hypernym_chain(s):
    "calculates the whole hypernym chain for a synset (and its hypernyms) as a list"
    "s: hypernyms() of a synset"
    second = s[0].hypernyms()
    y = []
    chain = []
    ls = len(second)
    if ls >= 1:
        t = s[0].hypernyms()
        y += hypernym_chain(t)
        chain = t+y
        return chain
    else: return chain

# %%
def key_chain(lem):
    "computes all sense-keys for all lemmata in a list"
    "lem: lemmas() of a synset"
    keys = []
    if lem is not None:
        for index in range(len(lem)):
            if lem[index].key() is not None:
                #keys = [] 
                keys = lem[index].key()
                print('Keys: ',keys)
            else: print('Keys: None')
        return keys

# %%
def lemmata_chain(chain, l='eng'):
    "computes all lemmata and their keys for each level of a hypernym_chain"
    "chain: a hypernym_chain()"
    "l: an omw language"
    for index in range(len(chain)):
        lem = [] 
        lem += chain[index].lemmas(l)
        print('Level '+ str(index+1) + ':')
        print('HyperLemmata: ',lem)
        key_chain(lem)

# %%
def omw_lang(w, p=None, l='eng', ln=None):
    "returns information for a word-form in a specific language"
    "w: a word"
    "p: optional part-of-speech"
    "l: an omw language"
    "ln: optional lexname"
    for synset in wn.synsets(w, lang=l, pos=p):
        if synset.lexname() == ln:
            print('Synset: ' + str(synset))
            print('Offset: ' + str(synset.offset()))
            print('Type: ' + str(synset.pos()))
            print('LexName: ' + str(synset.lexname()))
            print('Lemmata: ' + str(synset.lemma_names(l)))
            print('Definition: ' + str(synset.definition()))
            print('Examples: ' + str(synset.examples()))
            for hyper in synset.hypernyms():
                chain = hypernym_chain(synset.hypernyms())
                chain.insert(0,hyper)
                print('Hypernyms: ' + str(chain))
                lemmata_chain(chain,l)
            print('------------------------------------------------------------------------------------------------------------')
        if ln == None:
            print('Synset: ' + str(synset))
            print('Offset: ' + str(synset.offset()))
            print('Type: ' + str(synset.pos()))
            print('LexName: ' + str(synset.lexname()))
            print('Lemmata: ' + str(synset.lemma_names(l)))
            print('Definition: ' + str(synset.definition()))
            print('Examples: ' + str(synset.examples()))
            for hyper in synset.hypernyms():
                chain = hypernym_chain(synset.hypernyms())
                chain.insert(0,hyper)
                print('Hypernyms: ' + str(chain))
                lemmata_chain(chain,l)
            print('------------------------------------------------------------------------------------------------------------')

# %%
# Test examples

#spanish words
s=['avanzar', 'mover', 'irse', 'llegar', 'salir', 'subir', 'bajar', 
  'trepar', 'acercarse', 'gatear', 'subir', 'saltarse', 'caerse',
  'pasear', 'llevar', 'seguir', 'perseguir', 'ir_tras', 'salirse',
  'bajarse', 'subirse']

#english words
e=['advance', 'move', 'journey', 'arrive_at', 'bolt_out', 'climb_up',
  'climb_down', 'climb', 'approach', 'crawl_up', 'roll_up',
  'skip_over', 'fall_off', 'cruise_around', 'lead', 'follow',
  'pursue', 'chase', 'hop_off', 'hop_out', 'hop_in']

# %%
# Compare English and Spanish senses and hierarchies:
for i,(spa,eng) in enumerate(zip(s,e)):
    print('____________________________________________________________________________________________________________________')
    print([i], 'SPANISH ' + spa)
    omw_lang(spa,'v','spa','verb.motion')
    print([i], 'ENGLISH ' + eng)
    omw_lang(eng,'v','eng','verb.motion')
# Out:
# ____________________________________________________________________________________________________________________
# [0] SPANISH avanzar
# Synset: Synset('forge.v.04')
# Offset: 1884266
# Type: v
# LexName: verb.motion
# Lemmata: ['avanzar']
# Definition: move ahead steadily
# Examples: ['He forged ahead']
# Hypernyms: [Synset('advance.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  []
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('proceed.v.02')
# Offset: 1995549
# Type: v
# LexName: verb.motion
# Lemmata: ['avanzar', 'continuar', 'proceder', 'seguir']
# Definition: move ahead; travel onward in time or space
# Examples: ['We proceeded towards Washington', 'She continued in the direction of the hills', 'We are moving ahead in time now']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('reach.v.07')
# Offset: 2022162
# Type: v
# LexName: verb.motion
# Lemmata: ['avanzar', 'llegar', 'lograr', 'lograr_alcanzar', 'lograr_ser']
# Definition: reach a goal, e.g., "make the first team"
# Examples: ['We made it!', 'She may not make the grade']
# Hypernyms: [Synset('achieve.v.01'), Synset('succeed.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('achieve.v.01.alcanzar'), Lemma('achieve.v.01.lograr')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('succeed.v.01.conseguir'), Lemma('succeed.v.01.cumplir_lo_prometido'), Lemma('succeed.v.01.salir_adelante'), Lemma('succeed.v.01.tener_éxito'), Lemma('succeed.v.01.triumfar'), Lemma('succeed.v.01.triunfar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [0] ENGLISH advance
# Synset: Synset('advance.v.01')
# Offset: 1992503
# Type: v
# LexName: verb.motion
# Lemmata: ['advance', 'progress', 'pass_on', 'move_on', 'march_on', 'go_on']
# Definition: move forward, also in the metaphorical sense
# Examples: ['Time marches on']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('advance.v.05')
# Offset: 1993926
# Type: v
# LexName: verb.motion
# Lemmata: ['advance', 'bring_forward']
# Definition: cause to move forward
# Examples: ['Can you move the car seat forward?']
# Hypernyms: [Synset('move.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('move.v.02.move'), Lemma('move.v.02.displace')]
# Keys:  move%2:38:01::
# Keys:  displace%2:38:02::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('advance.v.11')
# Offset: 1994288
# Type: v
# LexName: verb.motion
# Lemmata: ['advance', 'set_ahead']
# Definition: move forward
# Examples: ['we have to advance clocks and watches when we travel eastward']
# Hypernyms: [Synset('set.v.08'), Synset('adjust.v.01'), Synset('change.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('set.v.08.set')]
# Keys:  set%2:30:02::
# Level 2:
# HyperLemmata:  [Lemma('adjust.v.01.adjust'), Lemma('adjust.v.01.set'), Lemma('adjust.v.01.correct')]
# Keys:  adjust%2:30:00::
# Keys:  set%2:30:00::
# Keys:  correct%2:30:09::
# Level 3:
# HyperLemmata:  [Lemma('change.v.01.change'), Lemma('change.v.01.alter'), Lemma('change.v.01.modify')]
# Keys:  change%2:30:01::
# Keys:  alter%2:30:01::
# Keys:  modify%2:30:10::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [1] SPANISH mover
# Synset: Synset('move.v.03')
# Offset: 1831531
# Type: v
# LexName: verb.motion
# Lemmata: ['mover', 'trasladar']
# Definition: move so as to change position, perform a nontranslational motion
# Examples: ['He moved his hand slightly to the right']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('move.v.02')
# Offset: 1850315
# Type: v
# LexName: verb.motion
# Lemmata: ['desplazar', 'mover']
# Definition: cause to move or shift into a new position or place, both in a concrete and in an abstract sense
# Examples: ['Move those boxes into the corner, please', "I'm moving my money to another bank", 'The director moved more responsibilities onto his new assistant']
# ------------------------------------------------------------------------------------------------------------
# [1] ENGLISH move
# Synset: Synset('travel.v.01')
# Offset: 1835496
# Type: v
# LexName: verb.motion
# Lemmata: ['travel', 'go', 'move', 'locomote']
# Definition: change location; move, travel, or proceed, also metaphorically
# Examples: ['How fast does your new car go?', 'We travelled from Rome to Naples by bus', 'The policemen went from door to door looking for the suspect', 'The soldiers moved towards the city in an attempt to take it before night fell', 'news travelled fast']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('move.v.02')
# Offset: 1850315
# Type: v
# LexName: verb.motion
# Lemmata: ['move', 'displace']
# Definition: cause to move or shift into a new position or place, both in a concrete and in an abstract sense
# Examples: ['Move those boxes into the corner, please', "I'm moving my money to another bank", 'The director moved more responsibilities onto his new assistant']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('move.v.03')
# Offset: 1831531
# Type: v
# LexName: verb.motion
# Lemmata: ['move']
# Definition: move so as to change position, perform a nontranslational motion
# Examples: ['He moved his hand slightly to the right']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('move.v.04')
# Offset: 1855606
# Type: v
# LexName: verb.motion
# Lemmata: ['move']
# Definition: change residence, affiliation, or place of employment
# Examples: ['We moved from Idaho to Nebraska', 'The basketball player moved from one team to another']
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [2] SPANISH irse
# Synset: Synset('walk_off.v.02')
# Offset: 2010082
# Type: v
# LexName: verb.motion
# Lemmata: ['irse', 'marcharse']
# Definition: go away from
# Examples: ['The actor walked off before he got his cue', 'I got annoyed and just walked off']
# Hypernyms: [Synset('leave.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('leave.v.01.dejar'), Lemma('leave.v.01.ir'), Lemma('leave.v.01.marchar'), Lemma('leave.v.01.partir'), Lemma('leave.v.01.salir')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [2] ENGLISH journey
# Synset: Synset('travel.v.02')
# Offset: 1845720
# Type: v
# LexName: verb.motion
# Lemmata: ['travel', 'journey']
# Definition: undertake a journey or trip
# Examples: []
# Hypernyms: [Synset('travel.v.03')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.03.travel'), Lemma('travel.v.03.trip'), Lemma('travel.v.03.jaunt')]
# Keys:  travel%2:38:01::
# Keys:  trip%2:38:02::
# Keys:  jaunt%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('travel.v.04')
# Offset: 1846916
# Type: v
# LexName: verb.motion
# Lemmata: ['travel', 'journey']
# Definition: travel upon or across
# Examples: ['travel the oceans']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [3] SPANISH llegar
# Synset: Synset('come.v.01')
# Offset: 1849221
# Type: v
# LexName: verb.motion
# Lemmata: ['llegar', 'venir']
# Definition: move toward, travel toward something or somebody or approach something or somebody
# Examples: ['He came singing down the road', 'Come with me to the Casbah', 'come down here!', 'come out of the closet!', 'come into the room']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('arrive.v.01')
# Offset: 2005948
# Type: v
# LexName: verb.motion
# Lemmata: ['alcanzar', 'llegar', 'venir']
# Definition: reach a destination; arrive by movement or progress
# Examples: ["She arrived home at 7 o'clock", "She didn't get to Chicago until after midnight"]
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('come.v.16')
# Offset: 2006709
# Type: v
# LexName: verb.motion
# Lemmata: ['entrar', 'llegar']
# Definition: be received
# Examples: ['News came in of the massacre in Rwanda']
# Hypernyms: [Synset('arrive.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('arrive.v.01.alcanzar'), Lemma('arrive.v.01.llegar'), Lemma('arrive.v.01.venir')]
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('access.v.02')
# Offset: 2007417
# Type: v
# LexName: verb.motion
# Lemmata: ['acceder', 'llegar', 'pretender']
# Definition: reach or gain access to
# Examples: ['How does one access the attic in this house?', 'I cannot get to the T.V. antenna, even if I climb on the roof']
# Hypernyms: [Synset('reach.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('reach.v.01.alcanzar'), Lemma('reach.v.01.ganar')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('pull_in.v.03')
# Offset: 2015384
# Type: v
# LexName: verb.motion
# Lemmata: ['arribar', 'entrar', 'hacer_su_llegada', 'ingresar', 'llegar']
# Definition: of trains; move into (a station)
# Examples: ['The bullet train drew into Tokyo Station']
# Hypernyms: [Synset('arrive.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('arrive.v.01.alcanzar'), Lemma('arrive.v.01.llegar'), Lemma('arrive.v.01.venir')]
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('reach.v.07')
# Offset: 2022162
# Type: v
# LexName: verb.motion
# Lemmata: ['avanzar', 'llegar', 'lograr', 'lograr_alcanzar', 'lograr_ser']
# Definition: reach a goal, e.g., "make the first team"
# Examples: ['We made it!', 'She may not make the grade']
# Hypernyms: [Synset('achieve.v.01'), Synset('succeed.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('achieve.v.01.alcanzar'), Lemma('achieve.v.01.lograr')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('succeed.v.01.conseguir'), Lemma('succeed.v.01.cumplir_lo_prometido'), Lemma('succeed.v.01.salir_adelante'), Lemma('succeed.v.01.tener_éxito'), Lemma('succeed.v.01.triumfar'), Lemma('succeed.v.01.triunfar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [3] ENGLISH arrive_at
# Synset: Synset('reach.v.01')
# Offset: 2020590
# Type: v
# LexName: verb.motion
# Lemmata: ['reach', 'make', 'attain', 'hit', 'arrive_at', 'gain']
# Definition: reach a destination, either real or abstract
# Examples: ['We hit Detroit by noon', 'The water reached the doorstep', 'We barely made it to the finish line', 'I have to hit the MAC machine before the weekend starts']
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [4] SPANISH salir
# Synset: Synset('go_out.v.02')
# Offset: 1842204
# Type: v
# LexName: verb.motion
# Lemmata: ['salir']
# Definition: leave the house to go somewhere
# Examples: ['We never went out when our children were small']
# Hypernyms: [Synset('leave.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('leave.v.01.dejar'), Lemma('leave.v.01.ir'), Lemma('leave.v.01.marchar'), Lemma('leave.v.01.partir'), Lemma('leave.v.01.salir')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('rise.v.16')
# Offset: 1970348
# Type: v
# LexName: verb.motion
# Lemmata: ['aparecer', 'ascender', 'elevarse', 'nacer', 'salir']
# Definition: come up, of celestial bodies
# Examples: ['The sun also rises', 'The sun uprising sees the dusk night fled...', 'Jupiter ascends']
# Hypernyms: [Synset('rise.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('rise.v.01.ascender'), Lemma('rise.v.01.subir')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('leave.v.01')
# Offset: 2009433
# Type: v
# LexName: verb.motion
# Lemmata: ['dejar', 'ir', 'marchar', 'partir', 'salir']
# Definition: go away from a place
# Examples: ['At what time does your train leave?', "She didn't leave until midnight", 'The ship leaves at midnight']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('go_out.v.03')
# Offset: 2011437
# Type: v
# LexName: verb.motion
# Lemmata: ['salir']
# Definition: take the field
# Examples: ['The soldiers went out on missions']
# Hypernyms: [Synset('leave.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('leave.v.01.dejar'), Lemma('leave.v.01.ir'), Lemma('leave.v.01.marchar'), Lemma('leave.v.01.partir'), Lemma('leave.v.01.salir')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('exit.v.01')
# Offset: 2015598
# Type: v
# LexName: verb.motion
# Lemmata: ['dejar', 'partir', 'salir']
# Definition: move out of or depart from
# Examples: ['leave the room', 'the fugitive has left the country']
# Hypernyms: [Synset('move.v.03')]
# Level 1:
# HyperLemmata:  [Lemma('move.v.03.mover'), Lemma('move.v.03.trasladar')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('sidetrack.v.01')
# Offset: 2066304
# Type: v
# LexName: verb.motion
# Lemmata: ['partir', 'salir']
# Definition: wander from a direct or straight course
# Examples: []
# Hypernyms: [Synset('deviate.v.01'), Synset('turn.v.01'), Synset('move.v.03')]
# Level 1:
# HyperLemmata:  [Lemma('deviate.v.01.desviar')]
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('turn.v.01.girar')]
# Keys: None
# Level 3:
# HyperLemmata:  [Lemma('move.v.03.mover'), Lemma('move.v.03.trasladar')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [4] ENGLISH bolt_out
# Synset: Synset('run_off.v.02')
# Offset: 2011040
# Type: v
# LexName: verb.motion
# Lemmata: ['run_off', 'run_out', 'bolt', 'bolt_out', 'beetle_off']
# Definition: leave suddenly and as if in a hurry
# Examples: ['The listeners bolted when he discussed his strange ideas', 'When she started to tell silly stories, I ran out']
# Hypernyms: [Synset('leave.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('leave.v.01.leave'), Lemma('leave.v.01.go_forth'), Lemma('leave.v.01.go_away')]
# Keys:  leave%2:38:01::
# Keys:  go_forth%2:38:00::
# Keys:  go_away%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [5] SPANISH subir
# Synset: Synset('uplift.v.03')
# Offset: 1873666
# Type: v
# LexName: verb.motion
# Lemmata: ['levantar', 'subir']
# Definition: lift up or elevate
# Examples: []
# Hypernyms: [Synset('push_up.v.01'), Synset('push.v.01'), Synset('move.v.02')]
# Level 1:
# HyperLemmata:  []
# Level 2:
# HyperLemmata:  [Lemma('push.v.01.apretar'), Lemma('push.v.01.empujar')]
# Keys: None
# Keys: None
# Level 3:
# HyperLemmata:  [Lemma('move.v.02.desplazar'), Lemma('move.v.02.mover')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('rise.v.01')
# Offset: 1968569
# Type: v
# LexName: verb.motion
# Lemmata: ['ascender', 'subir']
# Definition: move upward
# Examples: ['The fog lifted', 'The smoke arose from the forest fire', 'The mist uprose from the meadows']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('raise.v.02')
# Offset: 1974062
# Type: v
# LexName: verb.motion
# Lemmata: ['alzar', 'elevar', 'levantar', 'subir']
# Definition: raise from a lower to a higher position
# Examples: ['Raise your hands', 'Lift a load']
# Hypernyms: [Synset('move.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('move.v.02.desplazar'), Lemma('move.v.02.mover')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('rise.v.15')
# Offset: 1983134
# Type: v
# LexName: verb.motion
# Lemmata: ['incrementar', 'subir']
# Definition: increase in volume
# Examples: ['the dough rose slowly in the warm room']
# Hypernyms: [Synset('grow.v.02'), Synset('increase.v.01'), Synset('change_magnitude.v.01'), Synset('change.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('grow.v.02.crecer')]
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('increase.v.01.aumentar'), Lemma('increase.v.01.incrementar')]
# Keys: None
# Keys: None
# Level 3:
# HyperLemmata:  []
# Level 4:
# HyperLemmata:  [Lemma('change.v.02.cambiar')]
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('approach.v.01')
# Offset: 2053941
# Type: v
# LexName: verb.motion
# Lemmata: ['acercarse', 'aproximarse', 'subir', 'venir']
# Definition: move towards
# Examples: ['We were approaching our destination', 'They are drawing near', 'The enemy army came nearer and nearer']
# Hypernyms: [Synset('come.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('come.v.01.llegar'), Lemma('come.v.01.venir')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('ride.v.11')
# Offset: 2095545
# Type: v
# LexName: verb.motion
# Lemmata: ['subir', 'subirse']
# Definition: climb up on the body
# Examples: ['Shorts that ride up', 'This skirt keeps riding up my legs']
# Hypernyms: [Synset('climb.v.01'), Synset('rise.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('climb.v.01.montar'), Lemma('climb.v.01.trepar')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('rise.v.01.ascender'), Lemma('rise.v.01.subir')]
# Keys: None
# Keys: None
# Level 3:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [5] ENGLISH climb_up
# Synset: Synset('climb.v.01')
# Offset: 1921964
# Type: v
# LexName: verb.motion
# Lemmata: ['climb', 'climb_up', 'mount', 'go_up']
# Definition: go upward with gradual or continuous progress
# Examples: ['Did you ever climb up the hill behind your house?']
# Hypernyms: [Synset('rise.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('rise.v.01.rise'), Lemma('rise.v.01.lift'), Lemma('rise.v.01.arise'), Lemma('rise.v.01.move_up'), Lemma('rise.v.01.go_up'), Lemma('rise.v.01.come_up'), Lemma('rise.v.01.uprise')]
# Keys:  rise%2:38:00::
# Keys:  lift%2:38:03::
# Keys:  arise%2:38:04::
# Keys:  move_up%2:38:00::
# Keys:  go_up%2:38:00::
# Keys:  come_up%2:38:03::
# Keys:  uprise%2:38:01::
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('ascend.v.04')
# Offset: 2105657
# Type: v
# LexName: verb.motion
# Lemmata: ['ascend', 'climb_up']
# Definition: appear to be moving upward, as by means of tendrils
# Examples: ['the vine climbed up the side of the house']
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [6] SPANISH bajar
# Synset: Synset('ebb.v.01')
# Offset: 1903935
# Type: v
# LexName: verb.motion
# Lemmata: ['bajar']
# Definition: flow back or recede
# Examples: ['the tides ebbed at noon']
# Hypernyms: [Synset('fall_back.v.03'), Synset('withdraw.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  []
# Level 2:
# HyperLemmata:  []
# Level 3:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('lower.v.01')
# Offset: 1973125
# Type: v
# LexName: verb.motion
# Lemmata: ['bajar']
# Definition: move something or somebody to a lower position
# Examples: ['take down the vase from the shelf']
# Hypernyms: [Synset('move.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('move.v.02.desplazar'), Lemma('move.v.02.mover')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('drop.v.02')
# Offset: 1976841
# Type: v
# LexName: verb.motion
# Lemmata: ['bajar', 'caer']
# Definition: to fall vertically
# Examples: ['the bombs are dropping on enemy targets']
# Hypernyms: [Synset('descend.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('descend.v.01.descender')]
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [6] ENGLISH climb_down
# Synset: Synset('alight.v.02')
# Offset: 1978576
# Type: v
# LexName: verb.motion
# Lemmata: ['alight', 'climb_down']
# Definition: come down
# Examples: ['the birds alighted']
# Hypernyms: [Synset('descend.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('descend.v.01.descend'), Lemma('descend.v.01.fall'), Lemma('descend.v.01.go_down'), Lemma('descend.v.01.come_down')]
# Keys:  descend%2:38:00::
# Keys:  fall%2:38:00::
# Keys:  go_down%2:38:02::
# Keys:  come_down%2:38:00::
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [7] SPANISH trepar
# Synset: Synset('claw.v.01')
# Offset: 1914297
# Type: v
# LexName: verb.motion
# Lemmata: ['arañar', 'trepar']
# Definition: move as if by clawing, seizing, or digging
# Examples: ['They clawed their way to the top of the mountain']
# Hypernyms: [Synset('make.v.36'), Synset('pass.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  []
# Level 2:
# HyperLemmata:  [Lemma('pass.v.01.pasar')]
# Keys: None
# Level 3:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('climb.v.01')
# Offset: 1921964
# Type: v
# LexName: verb.motion
# Lemmata: ['montar', 'trepar']
# Definition: go upward with gradual or continuous progress
# Examples: ['Did you ever climb up the hill behind your house?']
# Hypernyms: [Synset('rise.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('rise.v.01.ascender'), Lemma('rise.v.01.subir')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('ramp.v.04')
# Offset: 1922754
# Type: v
# LexName: verb.motion
# Lemmata: ['trepar']
# Definition: creep up -- used especially of plants
# Examples: ['The roses ramped over the wall']
# Hypernyms: [Synset('climb.v.01'), Synset('rise.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('climb.v.01.montar'), Lemma('climb.v.01.trepar')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('rise.v.01.ascender'), Lemma('rise.v.01.subir')]
# Keys: None
# Keys: None
# Level 3:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('creep.v.03')
# Offset: 2060588
# Type: v
# LexName: verb.motion
# Lemmata: ['trepar']
# Definition: grow or spread, often in such a way as to cover (a surface)
# Examples: ['ivy crept over the walls of the university buildings']
# Hypernyms: [Synset('diffuse.v.01'), Synset('spread.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('diffuse.v.01.desplegarse'), Lemma('diffuse.v.01.difundir'), Lemma('diffuse.v.01.diseminar'), Lemma('diffuse.v.01.esparcir'), Lemma('diffuse.v.01.prppagar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('spread.v.01.desplegar'), Lemma('spread.v.01.extender')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [7] ENGLISH climb
# Synset: Synset('climb.v.01')
# Offset: 1921964
# Type: v
# LexName: verb.motion
# Lemmata: ['climb', 'climb_up', 'mount', 'go_up']
# Definition: go upward with gradual or continuous progress
# Examples: ['Did you ever climb up the hill behind your house?']
# Hypernyms: [Synset('rise.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('rise.v.01.rise'), Lemma('rise.v.01.lift'), Lemma('rise.v.01.arise'), Lemma('rise.v.01.move_up'), Lemma('rise.v.01.go_up'), Lemma('rise.v.01.come_up'), Lemma('rise.v.01.uprise')]
# Keys:  rise%2:38:00::
# Keys:  lift%2:38:03::
# Keys:  arise%2:38:04::
# Keys:  move_up%2:38:00::
# Keys:  go_up%2:38:00::
# Keys:  come_up%2:38:03::
# Keys:  uprise%2:38:01::
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('climb.v.02')
# Offset: 1923909
# Type: v
# LexName: verb.motion
# Lemmata: ['climb']
# Definition: move with difficulty, by grasping
# Examples: []
# Hypernyms: [Synset('move.v.03')]
# Level 1:
# HyperLemmata:  [Lemma('move.v.03.move')]
# Keys:  move%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('climb.v.04')
# Offset: 2037989
# Type: v
# LexName: verb.motion
# Lemmata: ['climb']
# Definition: slope upward
# Examples: ['The path climbed all the way to the top of the hill']
# Hypernyms: [Synset('slope.v.01'), Synset('lean.v.01'), Synset('bend.v.01'), Synset('change_shape.v.01'), Synset('change.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('slope.v.01.slope'), Lemma('slope.v.01.incline'), Lemma('slope.v.01.pitch')]
# Keys:  slope%2:38:00::
# Keys:  incline%2:38:00::
# Keys:  pitch%2:38:01::
# Level 2:
# HyperLemmata:  [Lemma('lean.v.01.lean'), Lemma('lean.v.01.tilt'), Lemma('lean.v.01.tip'), Lemma('lean.v.01.slant'), Lemma('lean.v.01.angle')]
# Keys:  lean%2:38:00::
# Keys:  tilt%2:38:00::
# Keys:  tip%2:38:01::
# Keys:  slant%2:38:00::
# Keys:  angle%2:38:00::
# Level 3:
# HyperLemmata:  [Lemma('bend.v.01.bend'), Lemma('bend.v.01.flex')]
# Keys:  bend%2:38:00::
# Keys:  flex%2:38:00::
# Level 4:
# HyperLemmata:  [Lemma('change_shape.v.01.change_shape'), Lemma('change_shape.v.01.change_form'), Lemma('change_shape.v.01.deform')]
# Keys:  change_shape%2:30:00::
# Keys:  change_form%2:30:00::
# Keys:  deform%2:30:02::
# Level 5:
# HyperLemmata:  [Lemma('change.v.02.change')]
# Keys:  change%2:30:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [8] SPANISH acercarse
# Synset: Synset('approach.v.01')
# Offset: 2053941
# Type: v
# LexName: verb.motion
# Lemmata: ['acercarse', 'aproximarse', 'subir', 'venir']
# Definition: move towards
# Examples: ['We were approaching our destination', 'They are drawing near', 'The enemy army came nearer and nearer']
# Hypernyms: [Synset('come.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('come.v.01.llegar'), Lemma('come.v.01.venir')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('close.v.12')
# Offset: 2054382
# Type: v
# LexName: verb.motion
# Lemmata: ['acercarse']
# Definition: draw near
# Examples: ['The probe closed with the space station']
# Hypernyms: [Synset('approach.v.01'), Synset('come.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('approach.v.01.acercarse'), Lemma('approach.v.01.aproximarse'), Lemma('approach.v.01.subir'), Lemma('approach.v.01.venir')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('come.v.01.llegar'), Lemma('come.v.01.venir')]
# Keys: None
# Keys: None
# Level 3:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [8] ENGLISH approach
# Synset: Synset('approach.v.01')
# Offset: 2053941
# Type: v
# LexName: verb.motion
# Lemmata: ['approach', 'near', 'come_on', 'go_up', 'draw_near', 'draw_close', 'come_near']
# Definition: move towards
# Examples: ['We were approaching our destination', 'They are drawing near', 'The enemy army came nearer and nearer']
# Hypernyms: [Synset('come.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('come.v.01.come'), Lemma('come.v.01.come_up')]
# Keys:  come%2:38:00::
# Keys:  come_up%2:38:02::
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('approach.v.04')
# Offset: 1849746
# Type: v
# LexName: verb.motion
# Lemmata: ['approach', 'come_near']
# Definition: come near in time
# Examples: ['Winter is approaching', 'approaching old age']
# Hypernyms: [Synset('come.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('come.v.01.come'), Lemma('come.v.01.come_up')]
# Keys:  come%2:38:00::
# Keys:  come_up%2:38:02::
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [9] SPANISH gatear
# [9] ENGLISH crawl_up
# ____________________________________________________________________________________________________________________
# [10] SPANISH subir
# Synset: Synset('uplift.v.03')
# Offset: 1873666
# Type: v
# LexName: verb.motion
# Lemmata: ['levantar', 'subir']
# Definition: lift up or elevate
# Examples: []
# Hypernyms: [Synset('push_up.v.01'), Synset('push.v.01'), Synset('move.v.02')]
# Level 1:
# HyperLemmata:  []
# Level 2:
# HyperLemmata:  [Lemma('push.v.01.apretar'), Lemma('push.v.01.empujar')]
# Keys: None
# Keys: None
# Level 3:
# HyperLemmata:  [Lemma('move.v.02.desplazar'), Lemma('move.v.02.mover')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('rise.v.01')
# Offset: 1968569
# Type: v
# LexName: verb.motion
# Lemmata: ['ascender', 'subir']
# Definition: move upward
# Examples: ['The fog lifted', 'The smoke arose from the forest fire', 'The mist uprose from the meadows']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('raise.v.02')
# Offset: 1974062
# Type: v
# LexName: verb.motion
# Lemmata: ['alzar', 'elevar', 'levantar', 'subir']
# Definition: raise from a lower to a higher position
# Examples: ['Raise your hands', 'Lift a load']
# Hypernyms: [Synset('move.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('move.v.02.desplazar'), Lemma('move.v.02.mover')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('rise.v.15')
# Offset: 1983134
# Type: v
# LexName: verb.motion
# Lemmata: ['incrementar', 'subir']
# Definition: increase in volume
# Examples: ['the dough rose slowly in the warm room']
# Hypernyms: [Synset('grow.v.02'), Synset('increase.v.01'), Synset('change_magnitude.v.01'), Synset('change.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('grow.v.02.crecer')]
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('increase.v.01.aumentar'), Lemma('increase.v.01.incrementar')]
# Keys: None
# Keys: None
# Level 3:
# HyperLemmata:  []
# Level 4:
# HyperLemmata:  [Lemma('change.v.02.cambiar')]
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('approach.v.01')
# Offset: 2053941
# Type: v
# LexName: verb.motion
# Lemmata: ['acercarse', 'aproximarse', 'subir', 'venir']
# Definition: move towards
# Examples: ['We were approaching our destination', 'They are drawing near', 'The enemy army came nearer and nearer']
# Hypernyms: [Synset('come.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('come.v.01.llegar'), Lemma('come.v.01.venir')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('ride.v.11')
# Offset: 2095545
# Type: v
# LexName: verb.motion
# Lemmata: ['subir', 'subirse']
# Definition: climb up on the body
# Examples: ['Shorts that ride up', 'This skirt keeps riding up my legs']
# Hypernyms: [Synset('climb.v.01'), Synset('rise.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('climb.v.01.montar'), Lemma('climb.v.01.trepar')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('rise.v.01.ascender'), Lemma('rise.v.01.subir')]
# Keys: None
# Keys: None
# Level 3:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [10] ENGLISH roll_up
# Synset: Synset('roll_up.v.03')
# Offset: 2006453
# Type: v
# LexName: verb.motion
# Lemmata: ['roll_up']
# Definition: arrive in a vehicle: "He rolled up in a black Mercedes"
# Examples: []
# Hypernyms: [Synset('arrive.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('arrive.v.01.arrive'), Lemma('arrive.v.01.get'), Lemma('arrive.v.01.come')]
# Keys:  arrive%2:38:00::
# Keys:  get%2:38:00::
# Keys:  come%2:38:04::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [11] SPANISH saltarse
# [11] ENGLISH skip_over
# ____________________________________________________________________________________________________________________
# [12] SPANISH caerse
# Synset: Synset('sink.v.01')
# Offset: 1985923
# Type: v
# LexName: verb.motion
# Lemmata: ['caer', 'caerse', 'dejar_caer', 'hundir']
# Definition: fall or descend to a lower place or level
# Examples: ['He sank to his knees']
# Hypernyms: [Synset('change_posture.v.01'), Synset('change.v.02')]
# Level 1:
# HyperLemmata:  []
# Level 2:
# HyperLemmata:  [Lemma('change.v.02.cambiar')]
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('come_out.v.05')
# Offset: 2097925
# Type: v
# LexName: verb.motion
# Lemmata: ['caerse', 'salirse']
# Definition: come off
# Examples: ['His hair and teeth fell out']
# Hypernyms: [Synset('issue.v.04')]
# Level 1:
# HyperLemmata:  [Lemma('issue.v.04.aparecer'), Lemma('issue.v.04.emerger'), Lemma('issue.v.04.salir'), Lemma('issue.v.04.surgir')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [12] ENGLISH fall_off
# ____________________________________________________________________________________________________________________
# [13] SPANISH pasear
# Synset: Synset('walk.v.02')
# Offset: 1907076
# Type: v
# LexName: verb.motion
# Lemmata: ['pasear']
# Definition: accompany or escort
# Examples: ["I'll walk you to your car"]
# Hypernyms: [Synset('accompany.v.02'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('accompany.v.02.acompañar')]
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('amble.v.01')
# Offset: 1918183
# Type: v
# LexName: verb.motion
# Lemmata: ['andar_sin_prisa', 'deambular', 'pasear', 'pasearse']
# Definition: walk leisurely
# Examples: []
# Hypernyms: [Synset('walk.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('walk.v.01.andar'), Lemma('walk.v.01.caminar')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('promenade.v.02')
# Offset: 1919226
# Type: v
# LexName: verb.motion
# Lemmata: ['pasear', 'salir_a_caminar']
# Definition: take a leisurely walk
# Examples: ['The ladies promenaded along the beach']
# Hypernyms: [Synset('walk.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('walk.v.01.andar'), Lemma('walk.v.01.caminar')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('parade.v.02')
# Offset: 1924505
# Type: v
# LexName: verb.motion
# Lemmata: ['desfilar', 'ir_juntos', 'pasear', 'salir_a_caminar']
# Definition: march in a procession
# Examples: ['the veterans paraded down the street']
# Hypernyms: [Synset('march.v.01'), Synset('walk.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('march.v.01.desfilar'), Lemma('march.v.01.ir_en_procesión'), Lemma('march.v.01.marchar')]
# Keys: None
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('walk.v.01.andar'), Lemma('walk.v.01.caminar')]
# Keys: None
# Keys: None
# Level 3:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('wheel.v.02')
# Offset: 2046441
# Type: v
# LexName: verb.motion
# Lemmata: ['empujar', 'pasear']
# Definition: wheel somebody or something
# Examples: []
# Hypernyms: [Synset('transport.v.01'), Synset('move.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('transport.v.01.transportar')]
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('move.v.02.desplazar'), Lemma('move.v.02.mover')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [13] ENGLISH cruise_around
# ____________________________________________________________________________________________________________________
# [14] SPANISH llevar
# Synset: Synset('pick_up.v.03')
# Offset: 1957107
# Type: v
# LexName: verb.motion
# Lemmata: ['llevar']
# Definition: give a passenger or a hitchhiker a lift
# Examples: ['We picked up a hitchhiker on the highway']
# Hypernyms: [Synset('transport.v.01'), Synset('move.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('transport.v.01.transportar')]
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('move.v.02.desplazar'), Lemma('move.v.02.mover')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('lead.v.01')
# Offset: 1999798
# Type: v
# LexName: verb.motion
# Lemmata: ['conducir', 'llevar']
# Definition: take somebody somewhere
# Examples: ['We lead him to our chief', 'can you take me to the main entrance?', 'He conducted us to the palace']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('bring.v.01')
# Offset: 2077656
# Type: v
# LexName: verb.motion
# Lemmata: ['acarrear', 'llevar', 'traer', 'transportar']
# Definition: take something or somebody with oneself somewhere
# Examples: ['Bring me the box from the other room', 'Take these letters to the boss', 'This brings me to the main point']
# Hypernyms: [Synset('transport.v.02'), Synset('move.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('transport.v.02.cargar'), Lemma('transport.v.02.transportar')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('move.v.02.desplazar'), Lemma('move.v.02.mover')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [14] ENGLISH lead
# Synset: Synset('lead.v.01')
# Offset: 1999798
# Type: v
# LexName: verb.motion
# Lemmata: ['lead', 'take', 'direct', 'conduct', 'guide']
# Definition: take somebody somewhere
# Examples: ['We lead him to our chief', 'can you take me to the main entrance?', 'He conducted us to the palace']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('lead.v.04')
# Offset: 1999423
# Type: v
# LexName: verb.motion
# Lemmata: ['lead', 'head']
# Definition: travel in front of; go in advance of others
# Examples: ['The procession was headed by John']
# Hypernyms: [Synset('precede.v.04'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('precede.v.04.precede'), Lemma('precede.v.04.lead')]
# Keys:  precede%2:38:00::
# Keys:  lead%2:38:02::
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('precede.v.04')
# Offset: 1999218
# Type: v
# LexName: verb.motion
# Lemmata: ['precede', 'lead']
# Definition: move ahead (of others) in time or space
# Examples: []
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [15] SPANISH seguir
# Synset: Synset('follow.v.04')
# Offset: 1991931
# Type: v
# LexName: verb.motion
# Lemmata: ['seguir']
# Definition: travel along a certain course
# Examples: ['follow the road', 'follow the trail']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('proceed.v.02')
# Offset: 1995549
# Type: v
# LexName: verb.motion
# Lemmata: ['avanzar', 'continuar', 'proceder', 'seguir']
# Definition: move ahead; travel onward in time or space
# Examples: ['We proceeded towards Washington', 'She continued in the direction of the hills', 'We are moving ahead in time now']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('follow.v.01')
# Offset: 1998432
# Type: v
# LexName: verb.motion
# Lemmata: ['seguir']
# Definition: to travel behind, go after, come after
# Examples: ['The ducklings followed their mother around the pond', 'Please follow the guide through the museum']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('elapse.v.01')
# Offset: 2072849
# Type: v
# LexName: verb.motion
# Lemmata: ['deslizarse', 'esfumarse', 'pasar', 'seguir', 'transcurrir', 'trascurrir']
# Definition: pass by
# Examples: ['three years elapsed']
# Hypernyms: [Synset('advance.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  []
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [15] ENGLISH follow
# Synset: Synset('follow.v.01')
# Offset: 1998432
# Type: v
# LexName: verb.motion
# Lemmata: ['follow']
# Definition: to travel behind, go after, come after
# Examples: ['The ducklings followed their mother around the pond', 'Please follow the guide through the museum']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('follow.v.04')
# Offset: 1991931
# Type: v
# LexName: verb.motion
# Lemmata: ['follow', 'travel_along']
# Definition: travel along a certain course
# Examples: ['follow the road', 'follow the trail']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('pursue.v.02')
# Offset: 2000868
# Type: v
# LexName: verb.motion
# Lemmata: ['pursue', 'follow']
# Definition: follow in or as if in pursuit
# Examples: ['The police car pursued the suspected attacker', 'Her bad deed followed her and haunted her dreams all her life']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [16] SPANISH perseguir
# Synset: Synset('pursue.v.02')
# Offset: 2000868
# Type: v
# LexName: verb.motion
# Lemmata: ['perseguir']
# Definition: follow in or as if in pursuit
# Examples: ['The police car pursued the suspected attacker', 'Her bad deed followed her and haunted her dreams all her life']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [16] ENGLISH pursue
# Synset: Synset('pursue.v.02')
# Offset: 2000868
# Type: v
# LexName: verb.motion
# Lemmata: ['pursue', 'follow']
# Definition: follow in or as if in pursuit
# Examples: ['The police car pursued the suspected attacker', 'Her bad deed followed her and haunted her dreams all her life']
# Hypernyms: [Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [17] SPANISH ir_tras
# [17] ENGLISH chase
# Synset: Synset('chase.v.01')
# Offset: 2001858
# Type: v
# LexName: verb.motion
# Lemmata: ['chase', 'chase_after', 'trail', 'tail', 'tag', 'give_chase', 'dog', 'go_after', 'track']
# Definition: go after with the intent to catch
# Examples: ['The policeman chased the mugger down the alley', 'the dog chased the rabbit']
# Hypernyms: [Synset('pursue.v.02'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('pursue.v.02.pursue'), Lemma('pursue.v.02.follow')]
# Keys:  pursue%2:38:00::
# Keys:  follow%2:38:13::
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [18] SPANISH salirse
# Synset: Synset('start.v.14')
# Offset: 2081946
# Type: v
# LexName: verb.motion
# Lemmata: ['resaltar', 'salirse', 'saltar', 'sobresalir']
# Definition: bulge outward
# Examples: ['His eyes popped']
# Hypernyms: [Synset('change_shape.v.01'), Synset('change.v.02')]
# Level 1:
# HyperLemmata:  []
# Level 2:
# HyperLemmata:  [Lemma('change.v.02.cambiar')]
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('come_out.v.05')
# Offset: 2097925
# Type: v
# LexName: verb.motion
# Lemmata: ['caerse', 'salirse']
# Definition: come off
# Examples: ['His hair and teeth fell out']
# Hypernyms: [Synset('issue.v.04')]
# Level 1:
# HyperLemmata:  [Lemma('issue.v.04.aparecer'), Lemma('issue.v.04.emerger'), Lemma('issue.v.04.salir'), Lemma('issue.v.04.surgir')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [18] ENGLISH hop_off
# ____________________________________________________________________________________________________________________
# [19] SPANISH bajarse
# Synset: Synset('hop_out.v.01')
# Offset: 1923732
# Type: v
# LexName: verb.motion
# Lemmata: ['bajarse', 'saltar_fuera']
# Definition: get out of quickly
# Examples: ['The officer hopped out when he spotted an illegally parked car']
# Hypernyms: [Synset('exit.v.01'), Synset('move.v.03')]
# Level 1:
# HyperLemmata:  [Lemma('exit.v.01.dejar'), Lemma('exit.v.01.partir'), Lemma('exit.v.01.salir')]
# Keys: None
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('move.v.03.mover'), Lemma('move.v.03.trasladar')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('unhorse.v.01')
# Offset: 1958452
# Type: v
# LexName: verb.motion
# Lemmata: ['agacharse', 'apearse', 'bajarse', 'desmontar', 'liviano']
# Definition: alight from (a horse)
# Examples: []
# Hypernyms: [Synset('descend.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('descend.v.01.descender')]
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [19] ENGLISH hop_out
# Synset: Synset('hop_out.v.01')
# Offset: 1923732
# Type: v
# LexName: verb.motion
# Lemmata: ['hop_out', 'get_off']
# Definition: get out of quickly
# Examples: ['The officer hopped out when he spotted an illegally parked car']
# Hypernyms: [Synset('exit.v.01'), Synset('move.v.03')]
# Level 1:
# HyperLemmata:  [Lemma('exit.v.01.exit'), Lemma('exit.v.01.go_out'), Lemma('exit.v.01.get_out'), Lemma('exit.v.01.leave')]
# Keys:  exit%2:38:00::
# Keys:  go_out%2:38:00::
# Keys:  get_out%2:38:01::
# Keys:  leave%2:38:00::
# Level 2:
# HyperLemmata:  [Lemma('move.v.03.move')]
# Keys:  move%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [20] SPANISH subirse
# Synset: Synset('hop.v.03')
# Offset: 1840736
# Type: v
# LexName: verb.motion
# Lemmata: ['pillar', 'subirse', 'tomar']
# Definition: travel by means of an aircraft, bus, etc.
# Examples: ['She hopped a train to Chicago', 'He hopped rides all over the country']
# Hypernyms: [Synset('travel.v.05'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('travel.v.05.viajar')]
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('ride.v.11')
# Offset: 2095545
# Type: v
# LexName: verb.motion
# Lemmata: ['subir', 'subirse']
# Definition: climb up on the body
# Examples: ['Shorts that ride up', 'This skirt keeps riding up my legs']
# Hypernyms: [Synset('climb.v.01'), Synset('rise.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('climb.v.01.montar'), Lemma('climb.v.01.trepar')]
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('rise.v.01.ascender'), Lemma('rise.v.01.subir')]
# Keys: None
# Keys: None
# Level 3:
# HyperLemmata:  [Lemma('travel.v.01.desplazarse'), Lemma('travel.v.01.ir'), Lemma('travel.v.01.moverse'), Lemma('travel.v.01.viajar')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [20] ENGLISH hop_in

# %%
m=['要','吃',' 喝', '拿']
e=['want', 'eat', 'drink', 'take']

# %%
# it does also work for Mandarin:

for i,(mand,eng) in enumerate(zip(m,e)):
    print('____________________________________________________________________________________________________________________')
    print([i], 'MANDARIN ' + mand)
    omw_lang(mand,'v','cmn')#,'verb.motion')
    print([i], 'ENGLISH ' + eng)
    omw_lang(eng,'v','eng')#,'verb.motion')
# Out:
# ____________________________________________________________________________________________________________________
# [0] MANDARIN 要
# Synset: Synset('want.v.02')
# Offset: 1188725
# Type: v
# LexName: verb.consumption
# Lemmata: ['必要', '必须', '要', '需', '需要']
# Definition: have need of
# Examples: ['This piano wants the attention of a competent tuner']
# Hypernyms: [Synset('be.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('be.v.01.是'), Lemma('be.v.01.有')]
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('desire.v.01')
# Offset: 1825237
# Type: v
# LexName: verb.emotion
# Lemmata: ['希望', '想', '想要', '愿意', '愿望', '期望', '要', '需要']
# Definition: feel or have a desire for; want strongly
# Examples: ['I want to go home now', 'I want my own room']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('necessitate.v.01')
# Offset: 2627934
# Type: v
# LexName: verb.stative
# Lemmata: ['必要', '要', '要求', '需', '需求', '需要']
# Definition: require as useful, just, or proper
# Examples: ['It takes nerve to do what she did', 'success usually requires hard work', 'This job asks a lot of patience and skill', 'This position demands a lot of personal sacrifice', 'This dinner calls for a spectacular dessert', "This intervention does not postulate a patient's consent"]
# ------------------------------------------------------------------------------------------------------------
# [0] ENGLISH want
# Synset: Synset('desire.v.01')
# Offset: 1825237
# Type: v
# LexName: verb.emotion
# Lemmata: ['desire', 'want']
# Definition: feel or have a desire for; want strongly
# Examples: ['I want to go home now', 'I want my own room']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('want.v.02')
# Offset: 1188725
# Type: v
# LexName: verb.consumption
# Lemmata: ['want', 'need', 'require']
# Definition: have need of
# Examples: ['This piano wants the attention of a competent tuner']
# Hypernyms: [Synset('be.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('be.v.01.be')]
# Keys:  be%2:42:03::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('want.v.03')
# Offset: 1317064
# Type: v
# LexName: verb.contact
# Lemmata: ['want']
# Definition: hunt or look for; want for a particular reason
# Examples: ['Your former neighbor is wanted by the FBI', 'Uncle Sam wants you']
# Hypernyms: [Synset('search.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('search.v.01.search'), Lemma('search.v.01.seek'), Lemma('search.v.01.look_for')]
# Keys:  search%2:35:00::
# Keys:  seek%2:35:00::
# Keys:  look_for%2:35:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('want.v.04')
# Offset: 709205
# Type: v
# LexName: verb.cognition
# Lemmata: ['want']
# Definition: wish or demand the presence of
# Examples: ['I want you here at noon!']
# Hypernyms: [Synset('demand.v.01'), Synset('request.v.01'), Synset('communicate.v.01'), Synset('convey.v.03'), Synset('transfer.v.02'), Synset('move.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('demand.v.01.demand')]
# Keys:  demand%2:32:00::
# Level 2:
# HyperLemmata:  [Lemma('request.v.01.request'), Lemma('request.v.01.bespeak'), Lemma('request.v.01.call_for'), Lemma('request.v.01.quest')]
# Keys:  request%2:32:01::
# Keys:  bespeak%2:32:00::
# Keys:  call_for%2:32:04::
# Keys:  quest%2:32:01::
# Level 3:
# HyperLemmata:  [Lemma('communicate.v.01.communicate'), Lemma('communicate.v.01.pass_on'), Lemma('communicate.v.01.pass'), Lemma('communicate.v.01.pass_along'), Lemma('communicate.v.01.put_across')]
# Keys:  communicate%2:32:01::
# Keys:  pass_on%2:32:00::
# Keys:  pass%2:32:01::
# Keys:  pass_along%2:32:00::
# Keys:  put_across%2:32:00::
# Level 4:
# HyperLemmata:  [Lemma('convey.v.03.convey'), Lemma('convey.v.03.transmit'), Lemma('convey.v.03.communicate')]
# Keys:  convey%2:40:10::
# Keys:  transmit%2:40:10::
# Keys:  communicate%2:40:10::
# Level 5:
# HyperLemmata:  [Lemma('transfer.v.02.transfer')]
# Keys:  transfer%2:40:01::
# Level 6:
# HyperLemmata:  [Lemma('move.v.02.move'), Lemma('move.v.02.displace')]
# Keys:  move%2:38:01::
# Keys:  displace%2:38:02::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('want.v.05')
# Offset: 2632567
# Type: v
# LexName: verb.stative
# Lemmata: ['want']
# Definition: be without, lack; be deficient in
# Examples: ['want courtesy', 'want the strength to go on living', 'flood victims wanting food and shelter']
# Hypernyms: [Synset('miss.v.06')]
# Level 1:
# HyperLemmata:  [Lemma('miss.v.06.miss'), Lemma('miss.v.06.lack')]
# Keys:  miss%2:42:00::
# Keys:  lack%2:42:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [1] MANDARIN 吃
# Synset: Synset('eat.v.01')
# Offset: 1168468
# Type: v
# LexName: verb.consumption
# Lemmata: ['吃', '吃东西', '食']
# Definition: take in solid food
# Examples: ['She was eating a banana', 'What did you eat for dinner last night?']
# Hypernyms: [Synset('consume.v.02')]
# Level 1:
# HyperLemmata:  []
# Hypernyms: [Synset('eat.v.02')]
# Level 1:
# HyperLemmata:  []
# ------------------------------------------------------------------------------------------------------------
# [1] ENGLISH eat
# Synset: Synset('eat.v.01')
# Offset: 1168468
# Type: v
# LexName: verb.consumption
# Lemmata: ['eat']
# Definition: take in solid food
# Examples: ['She was eating a banana', 'What did you eat for dinner last night?']
# Hypernyms: [Synset('consume.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('consume.v.02.consume'), Lemma('consume.v.02.ingest'), Lemma('consume.v.02.take_in'), Lemma('consume.v.02.take'), Lemma('consume.v.02.have')]
# Keys:  consume%2:34:00::
# Keys:  ingest%2:34:00::
# Keys:  take_in%2:34:00::
# Keys:  take%2:34:00::
# Keys:  have%2:34:00::
# Hypernyms: [Synset('eat.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('eat.v.02.eat')]
# Keys:  eat%2:34:01::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('eat.v.02')
# Offset: 1166351
# Type: v
# LexName: verb.consumption
# Lemmata: ['eat']
# Definition: eat a meal; take a meal
# Examples: ['We did not eat until 10 P.M. because there were so many phone calls', "I didn't eat yet, so I gladly accept your invitation"]
# Hypernyms: [Synset('consume.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('consume.v.02.consume'), Lemma('consume.v.02.ingest'), Lemma('consume.v.02.take_in'), Lemma('consume.v.02.take'), Lemma('consume.v.02.have')]
# Keys:  consume%2:34:00::
# Keys:  ingest%2:34:00::
# Keys:  take_in%2:34:00::
# Keys:  take%2:34:00::
# Keys:  have%2:34:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('feed.v.06')
# Offset: 1179865
# Type: v
# LexName: verb.consumption
# Lemmata: ['feed', 'eat']
# Definition: take in food; used of animals only
# Examples: ["This dog doesn't eat certain kinds of meat", 'What do whales eat?']
# Hypernyms: [Synset('consume.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('consume.v.02.consume'), Lemma('consume.v.02.ingest'), Lemma('consume.v.02.take_in'), Lemma('consume.v.02.take'), Lemma('consume.v.02.have')]
# Keys:  consume%2:34:00::
# Keys:  ingest%2:34:00::
# Keys:  take_in%2:34:00::
# Keys:  take%2:34:00::
# Keys:  have%2:34:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('eat.v.04')
# Offset: 1766273
# Type: v
# LexName: verb.emotion
# Lemmata: ['eat', 'eat_on']
# Definition: worry or cause anxiety in a persistent way
# Examples: ["What's eating you?"]
# Hypernyms: [Synset('worry.v.03'), Synset('perturb.v.01'), Synset('disturb.v.01'), Synset('affect.v.05')]
# Level 1:
# HyperLemmata:  [Lemma('worry.v.03.worry'), Lemma('worry.v.03.vex')]
# Keys:  worry%2:37:01::
# Keys:  vex%2:37:02::
# Level 2:
# HyperLemmata:  [Lemma('perturb.v.01.perturb'), Lemma('perturb.v.01.unhinge'), Lemma('perturb.v.01.disquiet'), Lemma('perturb.v.01.trouble'), Lemma('perturb.v.01.cark'), Lemma('perturb.v.01.distract'), Lemma('perturb.v.01.disorder')]
# Keys:  perturb%2:37:00::
# Keys:  unhinge%2:37:00::
# Keys:  disquiet%2:37:00::
# Keys:  trouble%2:37:00::
# Keys:  cark%2:37:00::
# Keys:  distract%2:37:02::
# Keys:  disorder%2:37:00::
# Level 3:
# HyperLemmata:  [Lemma('disturb.v.01.disturb'), Lemma('disturb.v.01.upset'), Lemma('disturb.v.01.trouble')]
# Keys:  disturb%2:37:00::
# Keys:  upset%2:37:00::
# Keys:  trouble%2:37:01::
# Level 4:
# HyperLemmata:  [Lemma('affect.v.05.affect'), Lemma('affect.v.05.impress'), Lemma('affect.v.05.move'), Lemma('affect.v.05.strike')]
# Keys:  affect%2:37:00::
# Keys:  impress%2:37:01::
# Keys:  move%2:37:00::
# Keys:  strike%2:37:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('consume.v.05')
# Offset: 1157517
# Type: v
# LexName: verb.consumption
# Lemmata: ['consume', 'eat_up', 'use_up', 'eat', 'deplete', 'exhaust', 'run_through', 'wipe_out']
# Definition: use up (resources or materials)
# Examples: ['this car consumes a lot of gas', 'We exhausted our savings', 'They run through 20 bottles of wine a week']
# Hypernyms: [Synset('spend.v.02'), Synset('pay.v.01'), Synset('give.v.03'), Synset('transfer.v.05')]
# Level 1:
# HyperLemmata:  [Lemma('spend.v.02.spend'), Lemma('spend.v.02.expend'), Lemma('spend.v.02.drop')]
# Keys:  spend%2:40:00::
# Keys:  expend%2:40:00::
# Keys:  drop%2:40:00::
# Level 2:
# HyperLemmata:  [Lemma('pay.v.01.pay')]
# Keys:  pay%2:40:00::
# Level 3:
# HyperLemmata:  [Lemma('give.v.03.give')]
# Keys:  give%2:40:00::
# Level 4:
# HyperLemmata:  [Lemma('transfer.v.05.transfer')]
# Keys:  transfer%2:40:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('corrode.v.01')
# Offset: 274283
# Type: v
# LexName: verb.change
# Lemmata: ['corrode', 'eat', 'rust']
# Definition: cause to deteriorate due to the action of water, air, or an acid
# Examples: ['The acid corroded the metal', 'The steady dripping of water rusted the metal stopper in the sink']
# Hypernyms: [Synset('damage.v.01'), Synset('change.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('damage.v.01.damage')]
# Keys:  damage%2:30:00::
# Level 2:
# HyperLemmata:  [Lemma('change.v.01.change'), Lemma('change.v.01.alter'), Lemma('change.v.01.modify')]
# Keys:  change%2:30:01::
# Keys:  alter%2:30:01::
# Keys:  modify%2:30:10::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [2] MANDARIN  喝
# [2] ENGLISH drink
# Synset: Synset('drink.v.01')
# Offset: 1170052
# Type: v
# LexName: verb.consumption
# Lemmata: ['drink', 'imbibe']
# Definition: take in liquids
# Examples: ['The patient must drink several liters each day', 'The children like to drink soda']
# Hypernyms: [Synset('consume.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('consume.v.02.consume'), Lemma('consume.v.02.ingest'), Lemma('consume.v.02.take_in'), Lemma('consume.v.02.take'), Lemma('consume.v.02.have')]
# Keys:  consume%2:34:00::
# Keys:  ingest%2:34:00::
# Keys:  take_in%2:34:00::
# Keys:  take%2:34:00::
# Keys:  have%2:34:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('drink.v.02')
# Offset: 1171183
# Type: v
# LexName: verb.consumption
# Lemmata: ['drink', 'booze', 'fuddle']
# Definition: consume alcohol
# Examples: ['We were up drinking all night']
# Hypernyms: [Synset('consume.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('consume.v.02.consume'), Lemma('consume.v.02.ingest'), Lemma('consume.v.02.take_in'), Lemma('consume.v.02.take'), Lemma('consume.v.02.have')]
# Keys:  consume%2:34:00::
# Keys:  ingest%2:34:00::
# Keys:  take_in%2:34:00::
# Keys:  take%2:34:00::
# Keys:  have%2:34:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('toast.v.02')
# Offset: 1175467
# Type: v
# LexName: verb.consumption
# Lemmata: ['toast', 'drink', 'pledge', 'salute', 'wassail']
# Definition: propose a toast to
# Examples: ['Let us toast the birthday girl!', "Let's drink to the New Year"]
# Hypernyms: [Synset('honor.v.01'), Synset('recognize.v.09'), Synset('prize.v.01'), Synset('see.v.05'), Synset('think.v.01'), Synset('evaluate.v.02'), Synset('think.v.03')]
# Level 1:
# HyperLemmata:  [Lemma('honor.v.01.honor'), Lemma('honor.v.01.honour'), Lemma('honor.v.01.reward')]
# Keys:  honor%2:41:00::
# Keys:  honour%2:41:00::
# Keys:  reward%2:41:01::
# Level 2:
# HyperLemmata:  [Lemma('recognize.v.09.recognize'), Lemma('recognize.v.09.recognise')]
# Keys:  recognize%2:41:01::
# Keys:  recognise%2:41:01::
# Level 3:
# HyperLemmata:  [Lemma('prize.v.01.prize'), Lemma('prize.v.01.value'), Lemma('prize.v.01.treasure'), Lemma('prize.v.01.appreciate')]
# Keys:  prize%2:40:00::
# Keys:  value%2:40:00::
# Keys:  treasure%2:40:00::
# Keys:  appreciate%2:40:00::
# Level 4:
# HyperLemmata:  [Lemma('see.v.05.see'), Lemma('see.v.05.consider'), Lemma('see.v.05.reckon'), Lemma('see.v.05.view'), Lemma('see.v.05.regard')]
# Keys:  see%2:31:00::
# Keys:  consider%2:31:00::
# Keys:  reckon%2:31:00::
# Keys:  view%2:31:00::
# Keys:  regard%2:31:00::
# Level 5:
# HyperLemmata:  [Lemma('think.v.01.think'), Lemma('think.v.01.believe'), Lemma('think.v.01.consider'), Lemma('think.v.01.conceive')]
# Keys:  think%2:31:01::
# Keys:  believe%2:31:04::
# Keys:  consider%2:31:08::
# Keys:  conceive%2:31:00::
# Level 6:
# HyperLemmata:  [Lemma('evaluate.v.02.evaluate'), Lemma('evaluate.v.02.pass_judgment'), Lemma('evaluate.v.02.judge')]
# Keys:  evaluate%2:31:01::
# Keys:  pass_judgment%2:31:00::
# Keys:  judge%2:31:00::
# Level 7:
# HyperLemmata:  [Lemma('think.v.03.think'), Lemma('think.v.03.cogitate'), Lemma('think.v.03.cerebrate')]
# Keys:  think%2:31:00::
# Keys:  cogitate%2:31:00::
# Keys:  cerebrate%2:31:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('drink_in.v.01')
# Offset: 737005
# Type: v
# LexName: verb.cognition
# Lemmata: ['drink_in', 'drink']
# Definition: be fascinated or spell-bound by; pay close attention to
# Examples: ['The mother drinks in every word of her son on the stage']
# Hypernyms: [Synset('steep.v.01'), Synset('concentrate.v.02'), Synset('think.v.03')]
# Level 1:
# HyperLemmata:  [Lemma('steep.v.01.steep'), Lemma('steep.v.01.immerse'), Lemma('steep.v.01.engulf'), Lemma('steep.v.01.plunge'), Lemma('steep.v.01.engross'), Lemma('steep.v.01.absorb'), Lemma('steep.v.01.soak_up')]
# Keys:  steep%2:31:00::
# Keys:  immerse%2:31:00::
# Keys:  engulf%2:31:00::
# Keys:  plunge%2:31:00::
# Keys:  engross%2:31:02::
# Keys:  absorb%2:31:06::
# Keys:  soak_up%2:31:00::
# Level 2:
# HyperLemmata:  [Lemma('concentrate.v.02.concentrate'), Lemma('concentrate.v.02.focus'), Lemma('concentrate.v.02.center'), Lemma('concentrate.v.02.centre'), Lemma('concentrate.v.02.pore'), Lemma('concentrate.v.02.rivet')]
# Keys:  concentrate%2:31:00::
# Keys:  focus%2:31:00::
# Keys:  center%2:31:00::
# Keys:  centre%2:31:00::
# Keys:  pore%2:31:00::
# Keys:  rivet%2:31:00::
# Level 3:
# HyperLemmata:  [Lemma('think.v.03.think'), Lemma('think.v.03.cogitate'), Lemma('think.v.03.cerebrate')]
# Keys:  think%2:31:00::
# Keys:  cogitate%2:31:00::
# Keys:  cerebrate%2:31:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('drink.v.05')
# Offset: 1172275
# Type: v
# LexName: verb.consumption
# Lemmata: ['drink', 'tope']
# Definition: drink excessive amounts of alcohol; be an alcoholic
# Examples: ['The husband drinks and beats his wife']
# Hypernyms: [Synset('use.v.02'), Synset('consume.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('use.v.02.use'), Lemma('use.v.02.habituate')]
# Keys:  use%2:34:02::
# Keys:  habituate%2:34:00::
# Level 2:
# HyperLemmata:  [Lemma('consume.v.02.consume'), Lemma('consume.v.02.ingest'), Lemma('consume.v.02.take_in'), Lemma('consume.v.02.take'), Lemma('consume.v.02.have')]
# Keys:  consume%2:34:00::
# Keys:  ingest%2:34:00::
# Keys:  take_in%2:34:00::
# Keys:  take%2:34:00::
# Keys:  have%2:34:00::
# ------------------------------------------------------------------------------------------------------------
# ____________________________________________________________________________________________________________________
# [3] MANDARIN 拿
# Synset: Synset('carry.v.30')
# Offset: 2001699
# Type: v
# LexName: verb.motion
# Lemmata: ['拿', '追踪']
# Definition: pursue a line of scent or be a bearer
# Examples: ['the dog was taught to fetch and carry']
# Hypernyms: [Synset('follow.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('follow.v.01.跟着'), Lemma('follow.v.01.跟随'), Lemma('follow.v.01.随')]
# Keys: None
# Keys: None
# Keys: None
# Level 2:
# HyperLemmata:  [Lemma('travel.v.01.离开'), Lemma('travel.v.01.移动'), Lemma('travel.v.01.行动'), Lemma('travel.v.01.行进'), Lemma('travel.v.01.运行')]
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('receive.v.01')
# Offset: 2210119
# Type: v
# LexName: verb.possession
# Lemmata: ['取得', '得到', '拿', '接到', '收到']
# Definition: get something; come into possession of
# Examples: ['receive payment', 'receive a gift', 'receive letters from the front']
# Hypernyms: [Synset('get.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('get.v.01.取得'), Lemma('get.v.01.得到'), Lemma('get.v.01.获得')]
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('have.v.17')
# Offset: 2355596
# Type: v
# LexName: verb.possession
# Lemmata: ['取得', '得到', '拿', '获得']
# Definition: achieve a point or goal
# Examples: ['Nicklaus had a 70', 'The Brazilian team got 4 goals', 'She made 29 points that day']
# Hypernyms: [Synset('score.v.01'), Synset('gain.v.05')]
# Level 1:
# HyperLemmata:  []
# Level 2:
# HyperLemmata:  []
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('fill.v.04')
# Offset: 2394183
# Type: v
# LexName: verb.social
# Lemmata: ['拿', '拿起']
# Definition: assume, as of positions or roles
# Examples: ['She took the job as director of development', 'he occupies the position of manager', 'the young prince will soon occupy the throne']
# Hypernyms: [Synset('work.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('work.v.02.做'), Lemma('work.v.02.做工'), Lemma('work.v.02.工作')]
# Keys: None
# Keys: None
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('carry.v.02')
# Offset: 2717102
# Type: v
# LexName: verb.stative
# Lemmata: ['拿', '拿起', '持有', '携带', '附有']
# Definition: have with oneself; have on one's person
# Examples: ['She always takes an umbrella', 'I always carry money', 'She packs a gun when she goes into the mountains']
# Hypernyms: [Synset('have.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('have.v.02.有')]
# Keys: None
# ------------------------------------------------------------------------------------------------------------
# [3] ENGLISH take
# Synset: Synset('take.v.01')
# Offset: 2599636
# Type: v
# LexName: verb.social
# Lemmata: ['take']
# Definition: carry out
# Examples: ['take action', 'take steps', 'take vengeance']
# Hypernyms: [Synset('act.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('act.v.01.act'), Lemma('act.v.01.move')]
# Keys:  act%2:41:00::
# Keys:  move%2:41:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.02')
# Offset: 2267989
# Type: v
# LexName: verb.possession
# Lemmata: ['take', 'occupy', 'use_up']
# Definition: require (time or space)
# Examples: ['It took three hours to get to work this morning', 'This event occupied a very short time']
# Hypernyms: [Synset('use.v.03')]
# Level 1:
# HyperLemmata:  [Lemma('use.v.03.use'), Lemma('use.v.03.expend')]
# Keys:  use%2:34:00::
# Keys:  expend%2:34:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('lead.v.01')
# Offset: 1999798
# Type: v
# LexName: verb.motion
# Lemmata: ['lead', 'take', 'direct', 'conduct', 'guide']
# Definition: take somebody somewhere
# Examples: ['We lead him to our chief', 'can you take me to the main entrance?', 'He conducted us to the palace']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.04')
# Offset: 1214265
# Type: v
# LexName: verb.contact
# Lemmata: ['take', 'get_hold_of']
# Definition: get into one's hands, take physically
# Examples: ['Take a cookie!', 'Can you take this bag, please']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('assume.v.03')
# Offset: 524682
# Type: v
# LexName: verb.change
# Lemmata: ['assume', 'acquire', 'adopt', 'take_on', 'take']
# Definition: take on a certain form, attribute, or aspect
# Examples: ['His voice took on a sad tone', 'The story took a new turn', 'he adopted an air of superiority', 'She assumed strange manners', 'The gods assume human or animal form in these fables']
# Hypernyms: [Synset('change.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('change.v.02.change')]
# Keys:  change%2:30:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.06')
# Offset: 624476
# Type: v
# LexName: verb.cognition
# Lemmata: ['take', 'read']
# Definition: interpret something in a certain way; convey a particular meaning or impression
# Examples: ['I read this address as a satire', 'How should I take this message?', "You can't take credit for this!"]
# Hypernyms: [Synset('interpret.v.01'), Synset('understand.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('interpret.v.01.interpret'), Lemma('interpret.v.01.construe'), Lemma('interpret.v.01.see')]
# Keys:  interpret%2:31:00::
# Keys:  construe%2:31:00::
# Keys:  see%2:31:13::
# Level 2:
# HyperLemmata:  [Lemma('understand.v.01.understand')]
# Keys:  understand%2:31:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('bring.v.01')
# Offset: 2077656
# Type: v
# LexName: verb.motion
# Lemmata: ['bring', 'convey', 'take']
# Definition: take something or somebody with oneself somewhere
# Examples: ['Bring me the box from the other room', 'Take these letters to the boss', 'This brings me to the main point']
# Hypernyms: [Synset('transport.v.02'), Synset('move.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('transport.v.02.transport'), Lemma('transport.v.02.carry')]
# Keys:  transport%2:35:00::
# Keys:  carry%2:35:02::
# Level 2:
# HyperLemmata:  [Lemma('move.v.02.move'), Lemma('move.v.02.displace')]
# Keys:  move%2:38:01::
# Keys:  displace%2:38:02::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.08')
# Offset: 2205272
# Type: v
# LexName: verb.possession
# Lemmata: ['take']
# Definition: take into one's possession
# Examples: ['We are taking an orphan from Romania', "I'll take three salmon steaks"]
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.09')
# Offset: 1842690
# Type: v
# LexName: verb.motion
# Lemmata: ['take']
# Definition: travel or go by means of a certain kind of transportation, or a certain route
# Examples: ['He takes the bus to work', 'She takes Route 1 to Newark']
# Hypernyms: [Synset('use.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('use.v.01.use'), Lemma('use.v.01.utilize'), Lemma('use.v.01.utilise'), Lemma('use.v.01.apply'), Lemma('use.v.01.employ')]
# Keys:  use%2:34:01::
# Keys:  utilize%2:34:00::
# Keys:  utilise%2:34:00::
# Keys:  apply%2:34:00::
# Keys:  employ%2:34:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('choose.v.01')
# Offset: 674607
# Type: v
# LexName: verb.cognition
# Lemmata: ['choose', 'take', 'select', 'pick_out']
# Definition: pick out, select, or choose from a number of alternatives
# Examples: ['Take any one of these cards', 'Choose a good husband for your daughter', 'She selected a pair of shoes from among the dozen the salesgirl had shown her']
# Hypernyms: [Synset('decide.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('decide.v.01.decide'), Lemma('decide.v.01.make_up_one's_mind'), Lemma('decide.v.01.determine')]
# Keys:  decide%2:31:00::
# Keys:  make_up_one's_mind%2:31:00::
# Keys:  determine%2:31:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('accept.v.02')
# Offset: 2236124
# Type: v
# LexName: verb.possession
# Lemmata: ['accept', 'take', 'have']
# Definition: receive willingly something given or offered
# Examples: ["The only girl who would have him was the miller's daughter", "I won't have this dog in my house!", 'Please accept my present']
# Hypernyms: [Synset('get.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('get.v.01.get'), Lemma('get.v.01.acquire')]
# Keys:  get%2:40:00::
# Keys:  acquire%2:40:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('fill.v.04')
# Offset: 2394183
# Type: v
# LexName: verb.social
# Lemmata: ['fill', 'take', 'occupy']
# Definition: assume, as of positions or roles
# Examples: ['She took the job as director of development', 'he occupies the position of manager', 'the young prince will soon occupy the throne']
# Hypernyms: [Synset('work.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('work.v.02.work'), Lemma('work.v.02.do_work')]
# Keys:  work%2:41:00::
# Keys:  do_work%2:41:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('consider.v.03')
# Offset: 734054
# Type: v
# LexName: verb.cognition
# Lemmata: ['consider', 'take', 'deal', 'look_at']
# Definition: take into consideration for exemplifying purposes
# Examples: ['Take the case of China', 'Consider the following case']
# Hypernyms: [Synset('think_about.v.01'), Synset('think.v.03')]
# Level 1:
# HyperLemmata:  [Lemma('think_about.v.01.think_about')]
# Keys:  think_about%2:31:05::
# Level 2:
# HyperLemmata:  [Lemma('think.v.03.think'), Lemma('think.v.03.cogitate'), Lemma('think.v.03.cerebrate')]
# Keys:  think%2:31:00::
# Keys:  cogitate%2:31:00::
# Keys:  cerebrate%2:31:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('necessitate.v.01')
# Offset: 2627934
# Type: v
# LexName: verb.stative
# Lemmata: ['necessitate', 'ask', 'postulate', 'need', 'require', 'take', 'involve', 'call_for', 'demand']
# Definition: require as useful, just, or proper
# Examples: ['It takes nerve to do what she did', 'success usually requires hard work', 'This job asks a lot of patience and skill', 'This position demands a lot of personal sacrifice', 'This dinner calls for a spectacular dessert', "This intervention does not postulate a patient's consent"]
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.15')
# Offset: 2109045
# Type: v
# LexName: verb.perception
# Lemmata: ['take']
# Definition: experience or feel or submit to
# Examples: ['Take a test', 'Take the plunge']
# Hypernyms: [Synset('experience.v.03'), Synset('undergo.v.01'), Synset('change.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('experience.v.03.experience'), Lemma('experience.v.03.receive'), Lemma('experience.v.03.have'), Lemma('experience.v.03.get')]
# Keys:  experience%2:39:00::
# Keys:  receive%2:39:03::
# Keys:  have%2:39:06::
# Keys:  get%2:39:00::
# Level 2:
# HyperLemmata:  [Lemma('undergo.v.01.undergo')]
# Keys:  undergo%2:39:04::
# Level 3:
# HyperLemmata:  [Lemma('change.v.02.change')]
# Keys:  change%2:30:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('film.v.01')
# Offset: 1002740
# Type: v
# LexName: verb.communication
# Lemmata: ['film', 'shoot', 'take']
# Definition: make a film or photograph of something
# Examples: ['take a scene', 'shoot a movie']
# Hypernyms: [Synset('record.v.01'), Synset('save.v.02'), Synset('keep.v.03'), Synset('have.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('record.v.01.record'), Lemma('record.v.01.enter'), Lemma('record.v.01.put_down')]
# Keys:  record%2:32:00::
# Keys:  enter%2:32:04::
# Keys:  put_down%2:32:05::
# Level 2:
# HyperLemmata:  [Lemma('save.v.02.save'), Lemma('save.v.02.preserve')]
# Keys:  save%2:40:00::
# Keys:  preserve%2:40:01::
# Level 3:
# HyperLemmata:  [Lemma('keep.v.03.keep'), Lemma('keep.v.03.hold_on')]
# Keys:  keep%2:40:00::
# Keys:  hold_on%2:40:00::
# Level 4:
# HyperLemmata:  [Lemma('have.v.01.have'), Lemma('have.v.01.have_got'), Lemma('have.v.01.hold')]
# Keys:  have%2:40:00::
# Keys:  have_got%2:40:00::
# Keys:  hold%2:40:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('remove.v.01')
# Offset: 173338
# Type: v
# LexName: verb.change
# Lemmata: ['remove', 'take', 'take_away', 'withdraw']
# Definition: remove something concrete, as by lifting, pushing, or taking off, or remove something abstract
# Examples: ['remove a threat', 'remove a wrapper', 'Remove the dirty dishes from the table', 'take the gun from your pocket', 'This machine withdraws heat from the environment']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('consume.v.02')
# Offset: 1156834
# Type: v
# LexName: verb.consumption
# Lemmata: ['consume', 'ingest', 'take_in', 'take', 'have']
# Definition: serve oneself to, or consume regularly
# Examples: ['Have another bowl of chicken soup!', "I don't take sugar in my coffee"]
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.19')
# Offset: 669762
# Type: v
# LexName: verb.cognition
# Lemmata: ['take', 'submit']
# Definition: accept or undergo, often unwillingly
# Examples: ['We took a pay cut']
# Hypernyms: [Synset('undergo.v.01'), Synset('change.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('undergo.v.01.undergo')]
# Keys:  undergo%2:39:04::
# Level 2:
# HyperLemmata:  [Lemma('change.v.02.change')]
# Keys:  change%2:30:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.20')
# Offset: 2209936
# Type: v
# LexName: verb.possession
# Lemmata: ['take', 'accept']
# Definition: make use of or accept for some purpose
# Examples: ['take a risk', 'take an opportunity']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.21')
# Offset: 2206619
# Type: v
# LexName: verb.possession
# Lemmata: ['take']
# Definition: take by force
# Examples: ['Hitler took the Baltic Republics', 'The army took the fort on the hill']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('assume.v.05')
# Offset: 1982395
# Type: v
# LexName: verb.motion
# Lemmata: ['assume', 'take', 'strike', 'take_up']
# Definition: occupy or take on
# Examples: ['He assumes the lotus position', 'She took her seat on the stage', 'We took our seats in the orchestra', 'She took up her position behind the tree', 'strike a pose']
# Hypernyms: [Synset('move.v.03')]
# Level 1:
# HyperLemmata:  [Lemma('move.v.03.move')]
# Keys:  move%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('accept.v.05')
# Offset: 2236624
# Type: v
# LexName: verb.possession
# Lemmata: ['accept', 'admit', 'take', 'take_on']
# Definition: admit into a group or community
# Examples: ['accept students for graduate study', "We'll have to vote on whether or not to admit a new member"]
# Hypernyms: [Synset('accept.v.02'), Synset('get.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('accept.v.02.accept'), Lemma('accept.v.02.take'), Lemma('accept.v.02.have')]
# Keys:  accept%2:40:00::
# Keys:  take%2:40:05::
# Keys:  have%2:40:05::
# Level 2:
# HyperLemmata:  [Lemma('get.v.01.get'), Lemma('get.v.01.acquire')]
# Keys:  get%2:40:00::
# Keys:  acquire%2:40:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.24')
# Offset: 523095
# Type: v
# LexName: verb.change
# Lemmata: ['take']
# Definition: ascertain or determine by measuring, computing or take a reading from a dial
# Examples: ['take a pulse', "A reading was taken of the earth's tremors"]
# Hypernyms: [Synset('receive.v.02'), Synset('change.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('receive.v.02.receive'), Lemma('receive.v.02.get'), Lemma('receive.v.02.find'), Lemma('receive.v.02.obtain'), Lemma('receive.v.02.incur')]
# Keys:  receive%2:30:01::
# Keys:  get%2:30:03::
# Keys:  find%2:30:00::
# Keys:  obtain%2:30:00::
# Keys:  incur%2:30:00::
# Level 2:
# HyperLemmata:  [Lemma('change.v.02.change')]
# Keys:  change%2:30:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('learn.v.04')
# Offset: 599992
# Type: v
# LexName: verb.cognition
# Lemmata: ['learn', 'study', 'read', 'take']
# Definition: be a student of a certain subject
# Examples: ['She is reading for the bar exam']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('claim.v.05')
# Offset: 756076
# Type: v
# LexName: verb.communication
# Lemmata: ['claim', 'take', 'exact']
# Definition: take as an undesirable consequence of some event or state of affairs
# Examples: ['the accident claimed three lives', 'The hard work took its toll on her']
# Hypernyms: [Synset('necessitate.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('necessitate.v.01.necessitate'), Lemma('necessitate.v.01.ask'), Lemma('necessitate.v.01.postulate'), Lemma('necessitate.v.01.need'), Lemma('necessitate.v.01.require'), Lemma('necessitate.v.01.take'), Lemma('necessitate.v.01.involve'), Lemma('necessitate.v.01.call_for'), Lemma('necessitate.v.01.demand')]
# Keys:  necessitate%2:42:00::
# Keys:  ask%2:42:00::
# Keys:  postulate%2:42:00::
# Keys:  need%2:42:00::
# Keys:  require%2:42:00::
# Keys:  take%2:42:00::
# Keys:  involve%2:42:07::
# Keys:  call_for%2:42:00::
# Keys:  demand%2:42:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.27')
# Offset: 2075857
# Type: v
# LexName: verb.motion
# Lemmata: ['take', 'make']
# Definition: head into a specified direction
# Examples: ['The escaped convict took to the hills', 'We made for the mountains']
# Hypernyms: [Synset('head.v.01'), Synset('proceed.v.02'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('head.v.01.head')]
# Keys:  head%2:38:00::
# Level 2:
# HyperLemmata:  [Lemma('proceed.v.02.proceed'), Lemma('proceed.v.02.go_forward'), Lemma('proceed.v.02.continue')]
# Keys:  proceed%2:38:00::
# Keys:  go_forward%2:38:00::
# Keys:  continue%2:38:00::
# Level 3:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('aim.v.01')
# Offset: 1151110
# Type: v
# LexName: verb.competition
# Lemmata: ['aim', 'take', 'train', 'take_aim', 'direct']
# Definition: point or cause to go (blows, weapons, or objects such as photographic equipment) towards
# Examples: ["Please don't aim at your little brother!", 'He trained his gun on the burglar', "Don't train your camera on the women", "Take a swipe at one's opponent"]
# Hypernyms: [Synset('position.v.01'), Synset('put.v.01'), Synset('move.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('position.v.01.position')]
# Keys:  position%2:38:00::
# Level 2:
# HyperLemmata:  [Lemma('put.v.01.put'), Lemma('put.v.01.set'), Lemma('put.v.01.place'), Lemma('put.v.01.pose'), Lemma('put.v.01.position'), Lemma('put.v.01.lay')]
# Keys:  put%2:35:00::
# Keys:  set%2:35:00::
# Keys:  place%2:35:00::
# Keys:  pose%2:35:02::
# Keys:  position%2:35:00::
# Keys:  lay%2:35:01::
# Level 3:
# HyperLemmata:  [Lemma('move.v.02.move'), Lemma('move.v.02.displace')]
# Keys:  move%2:38:01::
# Keys:  displace%2:38:02::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.29')
# Offset: 557404
# Type: v
# LexName: verb.change
# Lemmata: ['take']
# Definition: be seized or affected in a specified way
# Examples: ['take sick', 'be taken drunk']
# Hypernyms: [Synset('become.v.01'), Synset('change_state.v.01'), Synset('change.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('become.v.01.become'), Lemma('become.v.01.go'), Lemma('become.v.01.get')]
# Keys:  become%2:30:00::
# Keys:  go%2:30:04::
# Keys:  get%2:30:00::
# Level 2:
# HyperLemmata:  [Lemma('change_state.v.01.change_state'), Lemma('change_state.v.01.turn')]
# Keys:  change_state%2:30:00::
# Keys:  turn%2:30:04::
# Level 3:
# HyperLemmata:  [Lemma('change.v.02.change')]
# Keys:  change%2:30:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('carry.v.02')
# Offset: 2717102
# Type: v
# LexName: verb.stative
# Lemmata: ['carry', 'pack', 'take']
# Definition: have with oneself; have on one's person
# Examples: ['She always takes an umbrella', 'I always carry money', 'She packs a gun when she goes into the mountains']
# Hypernyms: [Synset('have.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('have.v.02.have'), Lemma('have.v.02.feature')]
# Keys:  have%2:42:00::
# Keys:  feature%2:42:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('lease.v.04')
# Offset: 2208537
# Type: v
# LexName: verb.possession
# Lemmata: ['lease', 'rent', 'hire', 'charter', 'engage', 'take']
# Definition: engage for service under a term of contract
# Examples: ['We took an apartment on a quiet street', "Let's rent a car", 'Shall we take a guide in Rome?']
# Hypernyms: [Synset('get.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('get.v.01.get'), Lemma('get.v.01.acquire')]
# Keys:  get%2:40:00::
# Keys:  acquire%2:40:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('subscribe.v.05')
# Offset: 2209745
# Type: v
# LexName: verb.possession
# Lemmata: ['subscribe', 'subscribe_to', 'take']
# Definition: receive or obtain regularly
# Examples: ['We take the Times every day']
# Hypernyms: [Synset('buy.v.01'), Synset('get.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('buy.v.01.buy'), Lemma('buy.v.01.purchase')]
# Keys:  buy%2:40:00::
# Keys:  purchase%2:40:00::
# Level 2:
# HyperLemmata:  [Lemma('get.v.01.get'), Lemma('get.v.01.acquire')]
# Keys:  get%2:40:00::
# Keys:  acquire%2:40:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.33')
# Offset: 2208118
# Type: v
# LexName: verb.possession
# Lemmata: ['take']
# Definition: buy, select
# Examples: ["I'll take a pound of that sausage"]
# Hypernyms: [Synset('buy.v.01'), Synset('get.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('buy.v.01.buy'), Lemma('buy.v.01.purchase')]
# Keys:  buy%2:40:00::
# Keys:  purchase%2:40:00::
# Level 2:
# HyperLemmata:  [Lemma('get.v.01.get'), Lemma('get.v.01.acquire')]
# Keys:  get%2:40:00::
# Keys:  acquire%2:40:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.34')
# Offset: 2201138
# Type: v
# LexName: verb.possession
# Lemmata: ['take']
# Definition: to get into a position of having, e.g., safety, comfort
# Examples: ['take shelter from the storm']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.35')
# Offset: 1427127
# Type: v
# LexName: verb.contact
# Lemmata: ['take', 'have']
# Definition: have sex with; archaic use
# Examples: ['He had taken this woman when she was most vulnerable']
# Hypernyms: [Synset('sleep_together.v.01'), Synset('copulate.v.01'), Synset('join.v.04'), Synset('connect.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('sleep_together.v.01.sleep_together'), Lemma('sleep_together.v.01.roll_in_the_hay'), Lemma('sleep_together.v.01.love'), Lemma('sleep_together.v.01.make_out'), Lemma('sleep_together.v.01.make_love'), Lemma('sleep_together.v.01.sleep_with'), Lemma('sleep_together.v.01.get_laid'), Lemma('sleep_together.v.01.have_sex'), Lemma('sleep_together.v.01.know'), Lemma('sleep_together.v.01.do_it'), Lemma('sleep_together.v.01.be_intimate'), Lemma('sleep_together.v.01.have_intercourse'), Lemma('sleep_together.v.01.have_it_away'), Lemma('sleep_together.v.01.have_it_off'), Lemma('sleep_together.v.01.screw'), Lemma('sleep_together.v.01.fuck'), Lemma('sleep_together.v.01.jazz'), Lemma('sleep_together.v.01.eff'), Lemma('sleep_together.v.01.hump'), Lemma('sleep_together.v.01.lie_with'), Lemma('sleep_together.v.01.bed'), Lemma('sleep_together.v.01.have_a_go_at_it'), Lemma('sleep_together.v.01.bang'), Lemma('sleep_together.v.01.get_it_on'), Lemma('sleep_together.v.01.bonk')]
# Keys:  sleep_together%2:35:00::
# Keys:  roll_in_the_hay%2:35:00::
# Keys:  love%2:35:00::
# Keys:  make_out%2:35:00::
# Keys:  make_love%2:35:00::
# Keys:  sleep_with%2:35:00::
# Keys:  get_laid%2:35:00::
# Keys:  have_sex%2:35:00::
# Keys:  know%2:35:00::
# Keys:  do_it%2:35:00::
# Keys:  be_intimate%2:35:00::
# Keys:  have_intercourse%2:35:00::
# Keys:  have_it_away%2:35:00::
# Keys:  have_it_off%2:35:00::
# Keys:  screw%2:35:04::
# Keys:  fuck%2:35:00::
# Keys:  jazz%2:35:00::
# Keys:  eff%2:35:00::
# Keys:  hump%2:35:00::
# Keys:  lie_with%2:35:00::
# Keys:  bed%2:35:00::
# Keys:  have_a_go_at_it%2:35:00::
# Keys:  bang%2:35:04::
# Keys:  get_it_on%2:35:00::
# Keys:  bonk%2:35:01::
# Level 2:
# HyperLemmata:  [Lemma('copulate.v.01.copulate'), Lemma('copulate.v.01.mate'), Lemma('copulate.v.01.pair'), Lemma('copulate.v.01.couple')]
# Keys:  copulate%2:35:00::
# Keys:  mate%2:35:00::
# Keys:  pair%2:35:00::
# Keys:  couple%2:35:00::
# Level 3:
# HyperLemmata:  [Lemma('join.v.04.join'), Lemma('join.v.04.conjoin')]
# Keys:  join%2:35:00::
# Keys:  conjoin%2:35:00::
# Level 4:
# HyperLemmata:  [Lemma('connect.v.01.connect'), Lemma('connect.v.01.link'), Lemma('connect.v.01.tie'), Lemma('connect.v.01.link_up')]
# Keys:  connect%2:35:00::
# Keys:  link%2:35:00::
# Keys:  tie%2:35:01::
# Keys:  link_up%2:35:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('claim.v.04')
# Offset: 758333
# Type: v
# LexName: verb.communication
# Lemmata: ['claim', 'take']
# Definition: lay claim to; as of an idea
# Examples: ['She took credit for the whole idea']
# Hypernyms: [Synset('affirm.v.02'), Synset('declare.v.01'), Synset('state.v.01'), Synset('express.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('affirm.v.02.affirm'), Lemma('affirm.v.02.verify'), Lemma('affirm.v.02.assert'), Lemma('affirm.v.02.avow'), Lemma('affirm.v.02.aver'), Lemma('affirm.v.02.swan'), Lemma('affirm.v.02.swear')]
# Keys:  affirm%2:32:00::
# Keys:  verify%2:32:03::
# Keys:  assert%2:32:00::
# Keys:  avow%2:32:00::
# Keys:  aver%2:32:00::
# Keys:  swan%2:32:00::
# Keys:  swear%2:32:03::
# Level 2:
# HyperLemmata:  [Lemma('declare.v.01.declare')]
# Keys:  declare%2:32:00::
# Level 3:
# HyperLemmata:  [Lemma('state.v.01.state'), Lemma('state.v.01.say'), Lemma('state.v.01.tell')]
# Keys:  state%2:32:00::
# Keys:  say%2:32:00::
# Keys:  tell%2:32:04::
# Level 4:
# HyperLemmata:  [Lemma('express.v.02.express'), Lemma('express.v.02.verbalize'), Lemma('express.v.02.verbalise'), Lemma('express.v.02.utter'), Lemma('express.v.02.give_tongue_to')]
# Keys:  express%2:32:00::
# Keys:  verbalize%2:32:03::
# Keys:  verbalise%2:32:03::
# Keys:  utter%2:32:01::
# Keys:  give_tongue_to%2:32:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('accept.v.08')
# Offset: 2741546
# Type: v
# LexName: verb.stative
# Lemmata: ['accept', 'take']
# Definition: be designed to hold or take
# Examples: ['This surface will not take the dye']
# Hypernyms: [Synset('be.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('be.v.01.be')]
# Keys:  be%2:42:03::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('contain.v.05')
# Offset: 2701210
# Type: v
# LexName: verb.stative
# Lemmata: ['contain', 'take', 'hold']
# Definition: be capable of holding or containing
# Examples: ["This box won't take all the items", 'The flask holds one gallon']
# Hypernyms: [Synset('be.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('be.v.01.be')]
# Keys:  be%2:42:03::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.39')
# Offset: 2590253
# Type: v
# LexName: verb.social
# Lemmata: ['take']
# Definition: develop a habit
# Examples: ['He took to visiting bars']
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('drive.v.16')
# Offset: 1930482
# Type: v
# LexName: verb.motion
# Lemmata: ['drive', 'take']
# Definition: proceed along in a vehicle
# Examples: ['We drive the turnpike to work']
# Hypernyms: [Synset('traverse.v.01'), Synset('pass.v.01'), Synset('travel.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('traverse.v.01.traverse'), Lemma('traverse.v.01.track'), Lemma('traverse.v.01.cover'), Lemma('traverse.v.01.cross'), Lemma('traverse.v.01.pass_over'), Lemma('traverse.v.01.get_over'), Lemma('traverse.v.01.get_across'), Lemma('traverse.v.01.cut_through'), Lemma('traverse.v.01.cut_across')]
# Keys:  traverse%2:38:00::
# Keys:  track%2:38:01::
# Keys:  cover%2:38:00::
# Keys:  cross%2:38:00::
# Keys:  pass_over%2:38:01::
# Keys:  get_over%2:38:00::
# Keys:  get_across%2:38:00::
# Keys:  cut_through%2:38:00::
# Keys:  cut_across%2:38:00::
# Level 2:
# HyperLemmata:  [Lemma('pass.v.01.pass'), Lemma('pass.v.01.go_through'), Lemma('pass.v.01.go_across')]
# Keys:  pass%2:38:00::
# Keys:  go_through%2:38:00::
# Keys:  go_across%2:38:00::
# Level 3:
# HyperLemmata:  [Lemma('travel.v.01.travel'), Lemma('travel.v.01.go'), Lemma('travel.v.01.move'), Lemma('travel.v.01.locomote')]
# Keys:  travel%2:38:00::
# Keys:  go%2:38:00::
# Keys:  move%2:38:03::
# Keys:  locomote%2:38:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('take.v.41')
# Offset: 1100830
# Type: v
# LexName: verb.competition
# Lemmata: ['take']
# Definition: obtain by winning
# Examples: ['Winner takes all', 'He took first prize']
# Hypernyms: [Synset('win.v.01')]
# Level 1:
# HyperLemmata:  [Lemma('win.v.01.win')]
# Keys:  win%2:33:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('contract.v.04')
# Offset: 87736
# Type: v
# LexName: verb.body
# Lemmata: ['contract', 'take', 'get']
# Definition: be stricken by an illness, fall victim to an illness
# Examples: ['He got AIDS', 'She came down with pneumonia', 'She took a chill']
# Hypernyms: [Synset('sicken.v.02'), Synset('worsen.v.01'), Synset('change_state.v.01'), Synset('change.v.02')]
# Level 1:
# HyperLemmata:  [Lemma('sicken.v.02.sicken'), Lemma('sicken.v.02.come_down')]
# Keys:  sicken%2:29:00::
# Keys:  come_down%2:29:00::
# Level 2:
# HyperLemmata:  [Lemma('worsen.v.01.worsen'), Lemma('worsen.v.01.decline')]
# Keys:  worsen%2:30:00::
# Keys:  decline%2:30:01::
# Level 3:
# HyperLemmata:  [Lemma('change_state.v.01.change_state'), Lemma('change_state.v.01.turn')]
# Keys:  change_state%2:30:00::
# Keys:  turn%2:30:04::
# Level 4:
# HyperLemmata:  [Lemma('change.v.02.change')]
# Keys:  change%2:30:00::
# ------------------------------------------------------------------------------------------------------------

# %%
# Example for a NOUN:
omw_lang('air','n', 'eng', ln='noun.location')
# Out:
# Synset: Synset('air.n.02')
# Offset: 8653314
# Type: n
# LexName: noun.location
# Lemmata: ['air']
# Definition: the region above the ground
# Examples: ['her hand stopped in mid air', 'he threw the ball into the air']
# Hypernyms: [Synset('region.n.01'), Synset('location.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# Level 1:
# HyperLemmata:  [Lemma('region.n.01.region'), Lemma('region.n.01.part')]
# Keys:  region%1:15:00::
# Keys:  part%1:15:00::
# Level 2:
# HyperLemmata:  [Lemma('location.n.01.location')]
# Keys:  location%1:03:00::
# Level 3:
# HyperLemmata:  [Lemma('object.n.01.object'), Lemma('object.n.01.physical_object')]
# Keys:  object%1:03:00::
# Keys:  physical_object%1:03:00::
# Level 4:
# HyperLemmata:  [Lemma('physical_entity.n.01.physical_entity')]
# Keys:  physical_entity%1:03:00::
# Level 5:
# HyperLemmata:  [Lemma('entity.n.01.entity')]
# Keys:  entity%1:03:00::
# ------------------------------------------------------------------------------------------------------------
# Synset: Synset('atmosphere.n.03')
# Offset: 8499057
# Type: n
# LexName: noun.location
# Lemmata: ['atmosphere', 'air']
# Definition: the mass of air surrounding the Earth
# Examples: ['there was great heat as the comet entered the atmosphere', 'it was exposed to the air']
# Hypernyms: [Synset('region.n.01'), Synset('location.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# Level 1:
# HyperLemmata:  [Lemma('region.n.01.region'), Lemma('region.n.01.part')]
# Keys:  region%1:15:00::
# Keys:  part%1:15:00::
# Level 2:
# HyperLemmata:  [Lemma('location.n.01.location')]
# Keys:  location%1:03:00::
# Level 3:
# HyperLemmata:  [Lemma('object.n.01.object'), Lemma('object.n.01.physical_object')]
# Keys:  object%1:03:00::
# Keys:  physical_object%1:03:00::
# Level 4:
# HyperLemmata:  [Lemma('physical_entity.n.01.physical_entity')]
# Keys:  physical_entity%1:03:00::
# Level 5:
# HyperLemmata:  [Lemma('entity.n.01.entity')]
# Keys:  entity%1:03:00::
# ------------------------------------------------------------------------------------------------------------
